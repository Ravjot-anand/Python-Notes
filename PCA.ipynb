# %%
'''
there is also the role of feature selection as we plot a grap between two feature, and which one have the best best data spread
Or selecting the one which has more variance
but in some case the variance of two feature or spread on the axsis is same therefore we cant chosse which one to choose
and then comes feature Extraction in role


*It is a method to reduce Dimensionality of the dataset without changing the essence of the dataset
Steps:

1.Standardize data
2.Compute covariance matrix
3.Find eigenvalues & eigenvectors
4.Select top components
5.Transform data
'''
